# %%
import utility
import os
import numpy as np

# %%
# load sequence
sequence1 = np.loadtxt("1hao_mfcc.csv", delimiter=",")
sequence2 = np.loadtxt("1hao_mfcc.csv", delimiter=",")
print(sequence1.shape, sequence2.shape)
# Out:
# [[-2.76310211e+02 -1.57858196e-14  1.97467458e-14 ... -8.17124146e-14
#    5.05752086e-15  2.84217094e-14]
#  [-2.76310211e+02 -1.57858196e-14  1.97467458e-14 ... -8.17124146e-14
#    5.05752086e-15  2.84217094e-14]
#  [-2.76310211e+02 -1.57858196e-14  1.97467458e-14 ... -8.17124146e-14
#    5.05752086e-15  2.84217094e-14]
#  ...
#  [-1.99556224e+02 -8.34438191e+00  6.53511548e-02 ... -5.57973902e-01
#   -9.32749603e-02 -9.09318161e-01]
#  [-1.98555667e+02 -1.00941632e+01  1.26008067e+00 ... -5.69861048e-01
#   -2.05917000e-01  8.30232734e-03]
#  [-1.77920233e+02 -1.55869935e+01 -1.17245553e+00 ...  2.52583783e-01
#   -2.39140240e+00  3.75330053e-01]]
